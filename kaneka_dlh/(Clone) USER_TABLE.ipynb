# %%
# %sql
CREATE OR REPLACE TABLE dev_first_usecase.gold.USER_TABLE(
  user_id STRING,
  cost_center STRING,
  charge_dept STRING,
  site_id STRING,
  master BOOLEAN
);

# %%
# %sql
DELETE FROM dev_first_usecase.gold.USER_TABLE

# %%
# %sql
INSERT INTO dev_first_usecase.gold.user_table VALUES
  ('tmp06500@kaneka.co.jp', '1550', '2141', '2',TRUE);
